# %%
#BUSCA EM LARGURA

from pprint import pprint
from copy import deepcopy

print('Insira o numero de discos:')
n_discos = int(input())

#Estado Inicial 
estado_inicial = {
    'A':[i for i in range(n_discos,0,-1)],
    'B':[],
    'C':[]
}

#Estado final
estado_final = {
    'A':[],
    'B':[],
    'C':[i for i in range(n_discos,0,-1)]
}

visitado = []

#Ações
acoes = [
    'mover_A_B',
    'mover_A_C',
    'mover_B_A',
    'mover_B_C',
    'mover_C_A',
    'mover_C_B'
]

def mover(estado, origem, destino):
    if not estado[origem]:
        return None
    if not estado[destino]:
        estado = deepcopy(estado)
        estado[destino].append(estado[origem].pop())
        return estado
    elif estado[destino][-1] > estado[origem][-1]:
        estado = deepcopy(estado)
        estado[destino].append(estado[origem].pop())
        return estado
    else:
        return None

#Modelo de transição
#Dados um estado e uma ação, o modelo de transição de estados retorna todos os estados vizinhos (fronteira)
def sucessor(estado):
    #gera todos os estados sucessores nao repetidos
    fronteira = [
        mover(estado,'A','B'),
        mover(estado,'A','C'),
        mover(estado,'B','A'),
        mover(estado,'B','C'),
        mover(estado,'C','A'),
        mover(estado,'C','B')
    ]
    return [estado for estado in fronteira if estado and estado]

#Modelo de transição
#Dados um estado e uma ação, o modelo de transição de estados retorna todos os estados vizinhos (fronteira)
def sucessor_p(estado):
    #gera todos os estados sucessores nao repetidos
    fronteira_p = [
        (estado[0] + 1, mover(estado[1],'A','B')),
        (estado[0] + 1, mover(estado[1],'A','C')),
        (estado[0] + 1, mover(estado[1],'B','A')),
        (estado[0] + 1, mover(estado[1],'B','C')),
        (estado[0] + 1, mover(estado[1],'C','A')),
        (estado[0] + 1, mover(estado[1],'C','B'))
    ]
    return [estado for estado in fronteira_p if estado[1] and estado[1] not in visitado]

print('ESTADO INICIAL')
pprint(estado_inicial)
ei = (0,estado_inicial)
sucessor_p(ei)

def solucao_p(estado):
    while visitado_p:
        profv = visitado_p[-1][0]
        if caminho_p:
            profc = caminho_p[-1][0]
        else:
            profc =10000
        if profv != profc:
            if caminho_p:
                vizinhos = sucessor(caminho_p[-1][1])
                if visitado_p[-1][1] in vizinhos:
                    caminho_p.append(visitado_p.pop())
                else:
                    visitado_p.pop()
            else:
                caminho_p.append(visitado_p.pop())
        else:
            visitado_p.pop()
    caminho_p.reverse()

#Busca em largura
def busca_largura(fronteira):
    if not fronteira:
        return None
    #remove o proximo elemento da fronteira (Busca em largura - FIFO)
    nodo = fronteira.pop(0)
    if nodo in visitado_p:
        return None
    print('SOLUCAO ATUAL')
    pprint(nodo)
    visitado_p.append(nodo)
    visitado.append(visitado_p[-1][1])
    #Testa o objetivo
    if nodo[1] == estado_final:
        print('SOLUCAO FINAL')
        pprint(nodo)
        solucao_p(nodo)
        while fronteira:
            fronteira.pop(0)
        return None
    #Gera os sucessores do estado atual
    vizinhos_p = sucessor_p(nodo)
    #print('VIZINHOS')
    #pprint(vizinhos)
    fronteira += vizinhos_p


caminho_p = []
vizinhos_p = []
visitado_p = []
fronteira = [(0,estado_inicial)]
while fronteira:
    busca_largura(fronteira)
print('Caminho')
pprint(caminho_p)
print('Resultado alcancado apos',len(visitado),'buscas.')
print('-------------------FIM LARGURA-------------------')
# Out:
# Insira o numero de discos:
#  6
# ESTADO INICIAL
# {'A': [6, 5, 4, 3, 2, 1], 'B': [], 'C': []}
# SOLUCAO ATUAL
# (0, {'A': [6, 5, 4, 3, 2, 1], 'B': [], 'C': []})
# SOLUCAO ATUAL
# (1, {'A': [6, 5, 4, 3, 2], 'B': [1], 'C': []})
# SOLUCAO ATUAL
# (1, {'A': [6, 5, 4, 3, 2], 'B': [], 'C': [1]})
# SOLUCAO ATUAL
# (2, {'A': [6, 5, 4, 3], 'B': [1], 'C': [2]})
# SOLUCAO ATUAL
# (2, {'A': [6, 5, 4, 3, 2], 'B': [], 'C': [1]})
# SOLUCAO ATUAL
# (2, {'A': [6, 5, 4, 3], 'B': [2], 'C': [1]})
# SOLUCAO ATUAL
# (3, {'A': [6, 5, 4, 3, 1], 'B': [], 'C': [2]})
# SOLUCAO ATUAL
# (3, {'A': [6, 5, 4, 3], 'B': [], 'C': [2, 1]})
# SOLUCAO ATUAL
# (3, {'A': [6, 5, 4, 3], 'B': [2], 'C': [1]})
# SOLUCAO ATUAL
# (3, {'A': [6, 5, 4, 3, 1], 'B': [2], 'C': []})
# SOLUCAO ATUAL
# (3, {'A': [6, 5, 4, 3], 'B': [2, 1], 'C': []})
# SOLUCAO ATUAL
# (4, {'A': [6, 5, 4, 3], 'B': [], 'C': [2, 1]})
# SOLUCAO ATUAL
# (4, {'A': [6, 5, 4, 3, 1], 'B': [2], 'C': []})
# SOLUCAO ATUAL
# (4, {'A': [6, 5, 4], 'B': [3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (4, {'A': [6, 5, 4, 3], 'B': [2, 1], 'C': []})
# SOLUCAO ATUAL
# (4, {'A': [6, 5, 4], 'B': [2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (5, {'A': [6, 5, 4], 'B': [3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (5, {'A': [6, 5, 4, 1], 'B': [3], 'C': [2]})
# SOLUCAO ATUAL
# (5, {'A': [6, 5, 4], 'B': [3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (5, {'A': [6, 5, 4], 'B': [2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (5, {'A': [6, 5, 4, 1], 'B': [2], 'C': [3]})
# SOLUCAO ATUAL
# (5, {'A': [6, 5, 4], 'B': [2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4, 1], 'B': [3], 'C': [2]})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4], 'B': [3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4, 1], 'B': [3, 2], 'C': []})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4, 2], 'B': [3, 1], 'C': []})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4, 1], 'B': [2], 'C': [3]})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4], 'B': [2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4, 1], 'B': [], 'C': [3, 2]})
# SOLUCAO ATUAL
# (6, {'A': [6, 5, 4, 2], 'B': [], 'C': [3, 1]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 1], 'B': [3, 2], 'C': []})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 2], 'B': [3, 1], 'C': []})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4], 'B': [3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4], 'B': [3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 2, 1], 'B': [3], 'C': []})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 2], 'B': [3], 'C': [1]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 1], 'B': [], 'C': [3, 2]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 2], 'B': [], 'C': [3, 1]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4], 'B': [1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4], 'B': [], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 2, 1], 'B': [], 'C': [3]})
# SOLUCAO ATUAL
# (7, {'A': [6, 5, 4, 2], 'B': [1], 'C': [3]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4], 'B': [3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4], 'B': [3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4, 2, 1], 'B': [3], 'C': []})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4, 2], 'B': [3], 'C': [1]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5], 'B': [3, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4, 2, 1], 'B': [], 'C': [3]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4], 'B': [1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4], 'B': [], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5, 4, 2], 'B': [1], 'C': [3]})
# SOLUCAO ATUAL
# (8, {'A': [6, 5], 'B': [4], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (9, {'A': [6, 5], 'B': [3, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (9, {'A': [6, 5, 1], 'B': [3, 2], 'C': [4]})
# SOLUCAO ATUAL
# (9, {'A': [6, 5], 'B': [3, 2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (9, {'A': [6, 5], 'B': [4], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (9, {'A': [6, 5, 1], 'B': [4], 'C': [3, 2]})
# SOLUCAO ATUAL
# (9, {'A': [6, 5], 'B': [4, 1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5, 1], 'B': [3, 2], 'C': [4]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5], 'B': [3, 2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5, 1], 'B': [3], 'C': [4, 2]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5, 2], 'B': [3], 'C': [4, 1]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5, 1], 'B': [4], 'C': [3, 2]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5], 'B': [4, 1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5, 1], 'B': [4, 2], 'C': [3]})
# SOLUCAO ATUAL
# (10, {'A': [6, 5, 2], 'B': [4, 1], 'C': [3]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 1], 'B': [3], 'C': [4, 2]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 2], 'B': [3], 'C': [4, 1]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5], 'B': [3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5], 'B': [3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 2, 1], 'B': [3], 'C': [4]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 2], 'B': [3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 1], 'B': [4, 2], 'C': [3]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 2], 'B': [4, 1], 'C': [3]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5], 'B': [4, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5], 'B': [4, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 2, 1], 'B': [4], 'C': [3]})
# SOLUCAO ATUAL
# (11, {'A': [6, 5, 2], 'B': [4], 'C': [3, 1]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5], 'B': [3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5], 'B': [3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 2, 1], 'B': [3], 'C': [4]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 2], 'B': [3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 3], 'B': [], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 2, 1], 'B': [], 'C': [4, 3]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5], 'B': [4, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5], 'B': [4, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 2, 1], 'B': [4], 'C': [3]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 2], 'B': [4], 'C': [3, 1]})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 3], 'B': [4, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (12, {'A': [6, 5, 2, 1], 'B': [4, 3], 'C': []})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 3], 'B': [], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 2, 1], 'B': [], 'C': [4, 3]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 3, 1], 'B': [], 'C': [4, 2]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 3], 'B': [1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 2], 'B': [1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 2], 'B': [], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 3], 'B': [4, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 2, 1], 'B': [4, 3], 'C': []})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 3, 1], 'B': [4, 2], 'C': []})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 3], 'B': [4, 2], 'C': [1]})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 2], 'B': [4, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (13, {'A': [6, 5, 2], 'B': [4, 3], 'C': [1]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3, 1], 'B': [], 'C': [4, 2]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3], 'B': [1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 2], 'B': [1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 2], 'B': [], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3, 1], 'B': [2], 'C': [4]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3, 2], 'B': [1], 'C': [4]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5], 'B': [1], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5], 'B': [2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3, 1], 'B': [4, 2], 'C': []})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3], 'B': [4, 2], 'C': [1]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 2], 'B': [4, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 2], 'B': [4, 3], 'C': [1]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3, 1], 'B': [4], 'C': [2]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5, 3, 2], 'B': [4], 'C': [1]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5], 'B': [4, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (14, {'A': [6, 5], 'B': [4, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 1], 'B': [2], 'C': [4]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 2], 'B': [1], 'C': [4]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [1], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3], 'B': [2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3], 'B': [2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 2, 1], 'B': [], 'C': [4]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 2], 'B': [], 'C': [4, 1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 1], 'B': [], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [], 'C': [4, 3, 2, 1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 1], 'B': [2], 'C': [4, 3]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [2, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 1], 'B': [4], 'C': [2]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 2], 'B': [4], 'C': [1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [4, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [4, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3], 'B': [4, 1], 'C': [2]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3], 'B': [4], 'C': [2, 1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 2, 1], 'B': [4], 'C': []})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 3, 2], 'B': [4, 1], 'C': []})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 1], 'B': [4, 3], 'C': [2]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [4, 3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (15, {'A': [6, 5, 1], 'B': [4, 3, 2], 'C': []})
# SOLUCAO ATUAL
# (15, {'A': [6, 5], 'B': [4, 3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3], 'B': [2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3], 'B': [2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3, 2, 1], 'B': [], 'C': [4]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3, 2], 'B': [], 'C': [4, 1]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 1], 'B': [], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5], 'B': [], 'C': [4, 3, 2, 1]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 1], 'B': [2], 'C': [4, 3]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5], 'B': [2, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3, 2, 1], 'B': [4], 'C': []})
# SOLUCAO ATUAL
# (16, {'A': [6], 'B': [5], 'C': [4, 3, 2, 1]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3], 'B': [4, 1], 'C': [2]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3], 'B': [4], 'C': [2, 1]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 3, 2], 'B': [4, 1], 'C': []})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 1], 'B': [4, 3], 'C': [2]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5], 'B': [4, 3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (16, {'A': [6, 5, 1], 'B': [4, 3, 2], 'C': []})
# SOLUCAO ATUAL
# (16, {'A': [6, 5], 'B': [4, 3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (16, {'A': [6], 'B': [4, 3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (17, {'A': [6], 'B': [5], 'C': [4, 3, 2, 1]})
# SOLUCAO ATUAL
# (17, {'A': [6, 1], 'B': [5], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (17, {'A': [6], 'B': [5, 1], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (17, {'A': [6], 'B': [4, 3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (17, {'A': [6, 1], 'B': [4, 3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (17, {'A': [6], 'B': [4, 3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (18, {'A': [6, 1], 'B': [5], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (18, {'A': [6], 'B': [5, 1], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (18, {'A': [6, 1], 'B': [5, 2], 'C': [4, 3]})
# SOLUCAO ATUAL
# (18, {'A': [6, 2], 'B': [5, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (18, {'A': [6, 1], 'B': [4, 3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (18, {'A': [6], 'B': [4, 3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (18, {'A': [6, 1], 'B': [4, 3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (18, {'A': [6, 2], 'B': [4, 3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (19, {'A': [6, 1], 'B': [5, 2], 'C': [4, 3]})
# SOLUCAO ATUAL
# (19, {'A': [6, 2], 'B': [5, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (19, {'A': [6], 'B': [5, 2, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (19, {'A': [6], 'B': [5, 2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (19, {'A': [6, 2, 1], 'B': [5], 'C': [4, 3]})
# SOLUCAO ATUAL
# (19, {'A': [6, 2], 'B': [5], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (19, {'A': [6, 1], 'B': [4, 3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (19, {'A': [6, 2], 'B': [4, 3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (19, {'A': [6], 'B': [4, 3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (19, {'A': [6], 'B': [4, 3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (19, {'A': [6, 2, 1], 'B': [4, 3], 'C': [5]})
# SOLUCAO ATUAL
# (19, {'A': [6, 2], 'B': [4, 3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (20, {'A': [6], 'B': [5, 2, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (20, {'A': [6], 'B': [5, 2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (20, {'A': [6, 2, 1], 'B': [5], 'C': [4, 3]})
# SOLUCAO ATUAL
# (20, {'A': [6, 2], 'B': [5], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (20, {'A': [6, 3], 'B': [5, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (20, {'A': [6, 2, 1], 'B': [5, 3], 'C': [4]})
# SOLUCAO ATUAL
# (20, {'A': [6], 'B': [4, 3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (20, {'A': [6], 'B': [4, 3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (20, {'A': [6, 2, 1], 'B': [4, 3], 'C': [5]})
# SOLUCAO ATUAL
# (20, {'A': [6, 2], 'B': [4, 3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (20, {'A': [6, 3], 'B': [4], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (20, {'A': [6, 2, 1], 'B': [4], 'C': [5, 3]})
# SOLUCAO ATUAL
# (21, {'A': [6, 3], 'B': [5, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (21, {'A': [6, 2, 1], 'B': [5, 3], 'C': [4]})
# SOLUCAO ATUAL
# (21, {'A': [6, 3, 1], 'B': [5, 2], 'C': [4]})
# SOLUCAO ATUAL
# (21, {'A': [6, 3], 'B': [5, 2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (21, {'A': [6, 2], 'B': [5, 3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (21, {'A': [6, 2], 'B': [5, 3], 'C': [4, 1]})
# SOLUCAO ATUAL
# (21, {'A': [6, 3], 'B': [4], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (21, {'A': [6, 2, 1], 'B': [4], 'C': [5, 3]})
# SOLUCAO ATUAL
# (21, {'A': [6, 3, 1], 'B': [4], 'C': [5, 2]})
# SOLUCAO ATUAL
# (21, {'A': [6, 3], 'B': [4, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (21, {'A': [6, 2], 'B': [4, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (21, {'A': [6, 2], 'B': [4], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3, 1], 'B': [5, 2], 'C': [4]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3], 'B': [5, 2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (22, {'A': [6, 2], 'B': [5, 3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (22, {'A': [6, 2], 'B': [5, 3], 'C': [4, 1]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3, 1], 'B': [5], 'C': [4, 2]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3, 2], 'B': [5], 'C': [4, 1]})
# SOLUCAO ATUAL
# (22, {'A': [6], 'B': [5, 3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (22, {'A': [6], 'B': [5, 3, 2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3, 1], 'B': [4], 'C': [5, 2]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3], 'B': [4, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (22, {'A': [6, 2], 'B': [4, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (22, {'A': [6, 2], 'B': [4], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3, 1], 'B': [4, 2], 'C': [5]})
# SOLUCAO ATUAL
# (22, {'A': [6, 3, 2], 'B': [4, 1], 'C': [5]})
# SOLUCAO ATUAL
# (22, {'A': [6], 'B': [4, 1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (22, {'A': [6], 'B': [4, 2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 1], 'B': [5], 'C': [4, 2]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 2], 'B': [5], 'C': [4, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [5, 3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [5, 3, 2], 'C': [4, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3], 'B': [5, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3], 'B': [5], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 2, 1], 'B': [5], 'C': [4]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 2], 'B': [5, 1], 'C': [4]})
# SOLUCAO ATUAL
# (23, {'A': [6, 1], 'B': [5, 3], 'C': [4, 2]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [5, 3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 1], 'B': [5, 3, 2], 'C': [4]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [5, 3, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 1], 'B': [4, 2], 'C': [5]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 2], 'B': [4, 1], 'C': [5]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [4, 1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [4, 2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3], 'B': [4, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3], 'B': [4, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 2, 1], 'B': [4], 'C': [5]})
# SOLUCAO ATUAL
# (23, {'A': [6, 3, 2], 'B': [4], 'C': [5, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 1], 'B': [4], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [4], 'C': [5, 3, 2, 1]})
# SOLUCAO ATUAL
# (23, {'A': [6, 1], 'B': [4, 2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (23, {'A': [6], 'B': [4, 2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3], 'B': [5, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3], 'B': [5], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3, 2, 1], 'B': [5], 'C': [4]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3, 2], 'B': [5, 1], 'C': [4]})
# SOLUCAO ATUAL
# (24, {'A': [6, 1], 'B': [5, 3], 'C': [4, 2]})
# SOLUCAO ATUAL
# (24, {'A': [6], 'B': [5, 3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (24, {'A': [6, 1], 'B': [5, 3, 2], 'C': [4]})
# SOLUCAO ATUAL
# (24, {'A': [6], 'B': [5, 3, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3, 2, 1], 'B': [5, 4], 'C': []})
# SOLUCAO ATUAL
# (24, {'A': [6, 4], 'B': [5, 3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (24, {'A': [6, 3], 'B': [4, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3], 'B': [4, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3, 2, 1], 'B': [4], 'C': [5]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3, 2], 'B': [4], 'C': [5, 1]})
# SOLUCAO ATUAL
# (24, {'A': [6, 1], 'B': [4], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (24, {'A': [6], 'B': [4], 'C': [5, 3, 2, 1]})
# SOLUCAO ATUAL
# (24, {'A': [6, 1], 'B': [4, 2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (24, {'A': [6], 'B': [4, 2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (24, {'A': [6, 3, 2, 1], 'B': [], 'C': [5, 4]})
# SOLUCAO ATUAL
# (24, {'A': [6, 4], 'B': [], 'C': [5, 3, 2, 1]})
# SOLUCAO ATUAL
# (25, {'A': [6, 3, 2, 1], 'B': [5, 4], 'C': []})
# SOLUCAO ATUAL
# (25, {'A': [6, 4], 'B': [5, 3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (25, {'A': [6, 3, 2], 'B': [5, 4, 1], 'C': []})
# SOLUCAO ATUAL
# (25, {'A': [6, 3, 2], 'B': [5, 4], 'C': [1]})
# SOLUCAO ATUAL
# (25, {'A': [6, 4, 1], 'B': [5, 3, 2], 'C': []})
# SOLUCAO ATUAL
# (25, {'A': [6, 4], 'B': [5, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (25, {'A': [6, 3, 2, 1], 'B': [], 'C': [5, 4]})
# SOLUCAO ATUAL
# (25, {'A': [6, 4], 'B': [], 'C': [5, 3, 2, 1]})
# SOLUCAO ATUAL
# (25, {'A': [6, 3, 2], 'B': [1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (25, {'A': [6, 3, 2], 'B': [], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (25, {'A': [6, 4, 1], 'B': [], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (25, {'A': [6, 4], 'B': [1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3, 2], 'B': [5, 4, 1], 'C': []})
# SOLUCAO ATUAL
# (26, {'A': [6, 3, 2], 'B': [5, 4], 'C': [1]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4, 1], 'B': [5, 3, 2], 'C': []})
# SOLUCAO ATUAL
# (26, {'A': [6, 4], 'B': [5, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3], 'B': [5, 4, 1], 'C': [2]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3], 'B': [5, 4, 2], 'C': [1]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4, 1], 'B': [5, 3], 'C': [2]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4, 2], 'B': [5, 3], 'C': [1]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3, 2], 'B': [1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3, 2], 'B': [], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4, 1], 'B': [], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4], 'B': [1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3], 'B': [1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (26, {'A': [6, 3], 'B': [2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4, 1], 'B': [2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (26, {'A': [6, 4, 2], 'B': [1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [5, 4, 1], 'C': [2]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [5, 4, 2], 'C': [1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 1], 'B': [5, 3], 'C': [2]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 2], 'B': [5, 3], 'C': [1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3, 1], 'B': [5, 4], 'C': [2]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [5, 4], 'C': [2, 1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3, 1], 'B': [5, 4, 2], 'C': []})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [5, 4, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (27, {'A': [6, 4], 'B': [5, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4], 'B': [5, 3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 2, 1], 'B': [5, 3], 'C': []})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 2], 'B': [5, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 1], 'B': [2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 2], 'B': [1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3, 1], 'B': [], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3, 1], 'B': [2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (27, {'A': [6, 3], 'B': [2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4], 'B': [2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4], 'B': [2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 2, 1], 'B': [], 'C': [5, 3]})
# SOLUCAO ATUAL
# (27, {'A': [6, 4, 2], 'B': [], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3, 1], 'B': [5, 4], 'C': [2]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3], 'B': [5, 4], 'C': [2, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3, 1], 'B': [5, 4, 2], 'C': []})
# SOLUCAO ATUAL
# (28, {'A': [6, 3], 'B': [5, 4, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (28, {'A': [6, 4], 'B': [5, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4], 'B': [5, 3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 2, 1], 'B': [5, 3], 'C': []})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 2], 'B': [5, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (28, {'A': [6], 'B': [5, 4, 3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6], 'B': [5, 4, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 3], 'B': [5], 'C': [2, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 2, 1], 'B': [5], 'C': [3]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3, 1], 'B': [], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3], 'B': [], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3, 1], 'B': [2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (28, {'A': [6, 3], 'B': [2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4], 'B': [2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4], 'B': [2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 2, 1], 'B': [], 'C': [5, 3]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 2], 'B': [], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6], 'B': [3], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (28, {'A': [6], 'B': [2, 1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 3], 'B': [2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (28, {'A': [6, 4, 2, 1], 'B': [3], 'C': [5]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [5, 4, 3], 'C': [2, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [5, 4, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 3], 'B': [5], 'C': [2, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 2, 1], 'B': [5], 'C': [3]})
# SOLUCAO ATUAL
# (29, {'A': [6, 1], 'B': [5, 4, 3], 'C': [2]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [5, 4, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (29, {'A': [6, 1], 'B': [5, 4, 2], 'C': [3]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [5, 4, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 3, 1], 'B': [5], 'C': [2]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 3], 'B': [5, 1], 'C': [2]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 2], 'B': [5, 1], 'C': [3]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 2], 'B': [5], 'C': [3, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [3], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [2, 1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 3], 'B': [2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 2, 1], 'B': [3], 'C': [5]})
# SOLUCAO ATUAL
# (29, {'A': [6, 1], 'B': [3], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [3, 1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (29, {'A': [6, 1], 'B': [2], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (29, {'A': [6], 'B': [2], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 3, 1], 'B': [2], 'C': [5]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 3], 'B': [2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 2], 'B': [3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (29, {'A': [6, 4, 2], 'B': [3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [5, 4, 3], 'C': [2]})
# SOLUCAO ATUAL
# (30, {'A': [6], 'B': [5, 4, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [5, 4, 2], 'C': [3]})
# SOLUCAO ATUAL
# (30, {'A': [6], 'B': [5, 4, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3, 1], 'B': [5], 'C': [2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3], 'B': [5, 1], 'C': [2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 2], 'B': [5, 1], 'C': [3]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 2], 'B': [5], 'C': [3, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [5, 4, 3, 2], 'C': []})
# SOLUCAO ATUAL
# (30, {'A': [6, 2], 'B': [5, 4, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [5, 4], 'C': [3, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 2], 'B': [5, 4], 'C': [3, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3, 1], 'B': [5, 2], 'C': []})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3, 2], 'B': [5, 1], 'C': []})
# SOLUCAO ATUAL
# (30, {'A': [6, 4], 'B': [5, 1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4], 'B': [5, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [3], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6], 'B': [3, 1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [2], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (30, {'A': [6], 'B': [2], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3, 1], 'B': [2], 'C': [5]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3], 'B': [2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 2], 'B': [3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 2], 'B': [3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [3, 2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (30, {'A': [6, 2], 'B': [3, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (30, {'A': [6, 1], 'B': [], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 2], 'B': [], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3, 1], 'B': [], 'C': [5, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4, 3, 2], 'B': [], 'C': [5, 1]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4], 'B': [3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (30, {'A': [6, 4], 'B': [3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 1], 'B': [5, 4, 3, 2], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [5, 4, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 1], 'B': [5, 4], 'C': [3, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [5, 4], 'C': [3, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 1], 'B': [5, 2], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 2], 'B': [5, 1], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [5, 1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [5, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [5, 4, 3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [5, 4, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2, 1], 'B': [5, 4, 3], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [5, 4, 3], 'C': [1]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [5, 4, 1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [5, 4], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2, 1], 'B': [5, 4], 'C': [3]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [5, 4, 1], 'C': [3]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3], 'B': [5, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3], 'B': [5, 2], 'C': [1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 2, 1], 'B': [5], 'C': []})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 2], 'B': [5], 'C': [1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 1], 'B': [5], 'C': [3, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [5], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 1], 'B': [5, 2], 'C': [3]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [5, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (31, {'A': [6, 1], 'B': [3, 2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [3, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (31, {'A': [6, 1], 'B': [], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 1], 'B': [], 'C': [5, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 2], 'B': [], 'C': [5, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [3, 2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [3, 2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2, 1], 'B': [3], 'C': [5, 4]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [3], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [1], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6], 'B': [], 'C': [5, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2, 1], 'B': [], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (31, {'A': [6, 2], 'B': [1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3], 'B': [1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3], 'B': [], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 2, 1], 'B': [], 'C': [5]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 3, 2], 'B': [1], 'C': [5]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 1], 'B': [3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4, 1], 'B': [3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (31, {'A': [6, 4], 'B': [3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [5, 4, 3, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [5, 4, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2, 1], 'B': [5, 4, 3], 'C': []})
# SOLUCAO ATUAL
# (32, {'A': [6, 2], 'B': [5, 4, 3], 'C': [1]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [5, 4, 1], 'C': [3, 2]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [5, 4], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2, 1], 'B': [5, 4], 'C': [3]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2], 'B': [5, 4, 1], 'C': [3]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3], 'B': [5, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3], 'B': [5, 2], 'C': [1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3, 2, 1], 'B': [5], 'C': []})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3, 2], 'B': [5], 'C': [1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 1], 'B': [5], 'C': [3, 2]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4], 'B': [5], 'C': [3, 2, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 1], 'B': [5, 2], 'C': [3]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4], 'B': [5, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (32, {'A': [], 'B': [5, 4, 3, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3, 2, 1], 'B': [], 'C': [5]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [3, 2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [3, 2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2, 1], 'B': [3], 'C': [5, 4]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2], 'B': [3], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [1], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (32, {'A': [6], 'B': [], 'C': [5, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2, 1], 'B': [], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (32, {'A': [6, 2], 'B': [1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3], 'B': [1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3], 'B': [], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 3, 2], 'B': [1], 'C': [5]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 1], 'B': [3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4], 'B': [3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4, 1], 'B': [3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (32, {'A': [6, 4], 'B': [3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (32, {'A': [], 'B': [6], 'C': [5, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (33, {'A': [], 'B': [5, 4, 3, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (33, {'A': [1], 'B': [5, 4, 3, 2], 'C': [6]})
# SOLUCAO ATUAL
# (33, {'A': [], 'B': [5, 4, 3, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (33, {'A': [], 'B': [6], 'C': [5, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (33, {'A': [1], 'B': [6], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (33, {'A': [], 'B': [6, 1], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (34, {'A': [1], 'B': [5, 4, 3, 2], 'C': [6]})
# SOLUCAO ATUAL
# (34, {'A': [], 'B': [5, 4, 3, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (34, {'A': [1], 'B': [5, 4, 3], 'C': [6, 2]})
# SOLUCAO ATUAL
# (34, {'A': [2], 'B': [5, 4, 3], 'C': [6, 1]})
# SOLUCAO ATUAL
# (34, {'A': [1], 'B': [6], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (34, {'A': [], 'B': [6, 1], 'C': [5, 4, 3, 2]})
# SOLUCAO ATUAL
# (34, {'A': [1], 'B': [6, 2], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (34, {'A': [2], 'B': [6, 1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (35, {'A': [1], 'B': [5, 4, 3], 'C': [6, 2]})
# SOLUCAO ATUAL
# (35, {'A': [2], 'B': [5, 4, 3], 'C': [6, 1]})
# SOLUCAO ATUAL
# (35, {'A': [], 'B': [5, 4, 3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (35, {'A': [], 'B': [5, 4, 3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (35, {'A': [2, 1], 'B': [5, 4, 3], 'C': [6]})
# SOLUCAO ATUAL
# (35, {'A': [2], 'B': [5, 4, 3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (35, {'A': [1], 'B': [6, 2], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (35, {'A': [2], 'B': [6, 1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (35, {'A': [], 'B': [6, 2, 1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (35, {'A': [], 'B': [6, 2], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (35, {'A': [2, 1], 'B': [6], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (35, {'A': [2], 'B': [6], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (36, {'A': [], 'B': [5, 4, 3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (36, {'A': [], 'B': [5, 4, 3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (36, {'A': [2, 1], 'B': [5, 4, 3], 'C': [6]})
# SOLUCAO ATUAL
# (36, {'A': [2], 'B': [5, 4, 3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (36, {'A': [3], 'B': [5, 4], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (36, {'A': [2, 1], 'B': [5, 4], 'C': [6, 3]})
# SOLUCAO ATUAL
# (36, {'A': [], 'B': [6, 2, 1], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (36, {'A': [], 'B': [6, 2], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (36, {'A': [2, 1], 'B': [6], 'C': [5, 4, 3]})
# SOLUCAO ATUAL
# (36, {'A': [2], 'B': [6], 'C': [5, 4, 3, 1]})
# SOLUCAO ATUAL
# (36, {'A': [3], 'B': [6, 2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (36, {'A': [2, 1], 'B': [6, 3], 'C': [5, 4]})
# SOLUCAO ATUAL
# (37, {'A': [3], 'B': [5, 4], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (37, {'A': [2, 1], 'B': [5, 4], 'C': [6, 3]})
# SOLUCAO ATUAL
# (37, {'A': [3, 1], 'B': [5, 4], 'C': [6, 2]})
# SOLUCAO ATUAL
# (37, {'A': [3], 'B': [5, 4, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (37, {'A': [2], 'B': [5, 4, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (37, {'A': [2], 'B': [5, 4], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (37, {'A': [3], 'B': [6, 2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (37, {'A': [2, 1], 'B': [6, 3], 'C': [5, 4]})
# SOLUCAO ATUAL
# (37, {'A': [3, 1], 'B': [6, 2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (37, {'A': [3], 'B': [6, 2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (37, {'A': [2], 'B': [6, 3, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (37, {'A': [2], 'B': [6, 3], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (38, {'A': [3, 1], 'B': [5, 4], 'C': [6, 2]})
# SOLUCAO ATUAL
# (38, {'A': [3], 'B': [5, 4, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (38, {'A': [2], 'B': [5, 4, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (38, {'A': [2], 'B': [5, 4], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (38, {'A': [3, 1], 'B': [5, 4, 2], 'C': [6]})
# SOLUCAO ATUAL
# (38, {'A': [3, 2], 'B': [5, 4, 1], 'C': [6]})
# SOLUCAO ATUAL
# (38, {'A': [], 'B': [5, 4, 1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (38, {'A': [], 'B': [5, 4, 2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (38, {'A': [3, 1], 'B': [6, 2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (38, {'A': [3], 'B': [6, 2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (38, {'A': [2], 'B': [6, 3, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (38, {'A': [2], 'B': [6, 3], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (38, {'A': [3, 1], 'B': [6], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (38, {'A': [3, 2], 'B': [6], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (38, {'A': [], 'B': [6, 3, 1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (38, {'A': [], 'B': [6, 3, 2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (39, {'A': [3, 1], 'B': [5, 4, 2], 'C': [6]})
# SOLUCAO ATUAL
# (39, {'A': [3, 2], 'B': [5, 4, 1], 'C': [6]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [5, 4, 1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [5, 4, 2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (39, {'A': [3], 'B': [5, 4, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (39, {'A': [3], 'B': [5, 4, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (39, {'A': [3, 2, 1], 'B': [5, 4], 'C': [6]})
# SOLUCAO ATUAL
# (39, {'A': [3, 2], 'B': [5, 4], 'C': [6, 1]})
# SOLUCAO ATUAL
# (39, {'A': [1], 'B': [5, 4], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [5, 4], 'C': [6, 3, 2, 1]})
# SOLUCAO ATUAL
# (39, {'A': [1], 'B': [5, 4, 2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [5, 4, 2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (39, {'A': [3, 1], 'B': [6], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (39, {'A': [3, 2], 'B': [6], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [6, 3, 1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [6, 3, 2], 'C': [5, 4, 1]})
# SOLUCAO ATUAL
# (39, {'A': [3], 'B': [6, 1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (39, {'A': [3], 'B': [6], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (39, {'A': [3, 2, 1], 'B': [6], 'C': [5, 4]})
# SOLUCAO ATUAL
# (39, {'A': [3, 2], 'B': [6, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (39, {'A': [1], 'B': [6, 3], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [6, 3], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (39, {'A': [1], 'B': [6, 3, 2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (39, {'A': [], 'B': [6, 3, 2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (40, {'A': [3], 'B': [5, 4, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (40, {'A': [3], 'B': [5, 4, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (40, {'A': [3, 2, 1], 'B': [5, 4], 'C': [6]})
# SOLUCAO ATUAL
# (40, {'A': [3, 2], 'B': [5, 4], 'C': [6, 1]})
# SOLUCAO ATUAL
# (40, {'A': [1], 'B': [5, 4], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (40, {'A': [], 'B': [5, 4], 'C': [6, 3, 2, 1]})
# SOLUCAO ATUAL
# (40, {'A': [1], 'B': [5, 4, 2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (40, {'A': [], 'B': [5, 4, 2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (40, {'A': [3, 2, 1], 'B': [5], 'C': [6, 4]})
# SOLUCAO ATUAL
# (40, {'A': [4], 'B': [5], 'C': [6, 3, 2, 1]})
# SOLUCAO ATUAL
# (40, {'A': [3], 'B': [6, 1], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (40, {'A': [3], 'B': [6], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (40, {'A': [3, 2, 1], 'B': [6], 'C': [5, 4]})
# SOLUCAO ATUAL
# (40, {'A': [3, 2], 'B': [6, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (40, {'A': [1], 'B': [6, 3], 'C': [5, 4, 2]})
# SOLUCAO ATUAL
# (40, {'A': [], 'B': [6, 3], 'C': [5, 4, 2, 1]})
# SOLUCAO ATUAL
# (40, {'A': [1], 'B': [6, 3, 2], 'C': [5, 4]})
# SOLUCAO ATUAL
# (40, {'A': [], 'B': [6, 3, 2, 1], 'C': [5, 4]})
# SOLUCAO ATUAL
# (40, {'A': [3, 2, 1], 'B': [6, 4], 'C': [5]})
# SOLUCAO ATUAL
# (40, {'A': [4], 'B': [6, 3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (41, {'A': [3, 2, 1], 'B': [5], 'C': [6, 4]})
# SOLUCAO ATUAL
# (41, {'A': [4], 'B': [5], 'C': [6, 3, 2, 1]})
# SOLUCAO ATUAL
# (41, {'A': [3, 2], 'B': [5, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (41, {'A': [3, 2], 'B': [5], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (41, {'A': [4, 1], 'B': [5], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (41, {'A': [4], 'B': [5, 1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (41, {'A': [3, 2, 1], 'B': [6, 4], 'C': [5]})
# SOLUCAO ATUAL
# (41, {'A': [4], 'B': [6, 3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (41, {'A': [3, 2], 'B': [6, 4, 1], 'C': [5]})
# SOLUCAO ATUAL
# (41, {'A': [3, 2], 'B': [6, 4], 'C': [5, 1]})
# SOLUCAO ATUAL
# (41, {'A': [4, 1], 'B': [6, 3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (41, {'A': [4], 'B': [6, 3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (42, {'A': [3, 2], 'B': [5, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (42, {'A': [3, 2], 'B': [5], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (42, {'A': [4, 1], 'B': [5], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (42, {'A': [4], 'B': [5, 1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (42, {'A': [3], 'B': [5, 1], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (42, {'A': [3], 'B': [5, 2], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (42, {'A': [4, 1], 'B': [5, 2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (42, {'A': [4, 2], 'B': [5, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (42, {'A': [3, 2], 'B': [6, 4, 1], 'C': [5]})
# SOLUCAO ATUAL
# (42, {'A': [3, 2], 'B': [6, 4], 'C': [5, 1]})
# SOLUCAO ATUAL
# (42, {'A': [4, 1], 'B': [6, 3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (42, {'A': [4], 'B': [6, 3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (42, {'A': [3], 'B': [6, 4, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (42, {'A': [3], 'B': [6, 4, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (42, {'A': [4, 1], 'B': [6, 3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (42, {'A': [4, 2], 'B': [6, 3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [5, 1], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [5, 2], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (43, {'A': [4, 1], 'B': [5, 2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (43, {'A': [4, 2], 'B': [5, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (43, {'A': [3, 1], 'B': [5], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [5], 'C': [6, 4, 2, 1]})
# SOLUCAO ATUAL
# (43, {'A': [3, 1], 'B': [5, 2], 'C': [6, 4]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [5, 2, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (43, {'A': [4], 'B': [5, 2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (43, {'A': [4], 'B': [5, 2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (43, {'A': [4, 2, 1], 'B': [5], 'C': [6, 3]})
# SOLUCAO ATUAL
# (43, {'A': [4, 2], 'B': [5], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [6, 4, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [6, 4, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (43, {'A': [4, 1], 'B': [6, 3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (43, {'A': [4, 2], 'B': [6, 3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (43, {'A': [3, 1], 'B': [6, 4], 'C': [5, 2]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [6, 4], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (43, {'A': [3, 1], 'B': [6, 4, 2], 'C': [5]})
# SOLUCAO ATUAL
# (43, {'A': [3], 'B': [6, 4, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (43, {'A': [4], 'B': [6, 3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (43, {'A': [4], 'B': [6, 3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (43, {'A': [4, 2, 1], 'B': [6, 3], 'C': [5]})
# SOLUCAO ATUAL
# (43, {'A': [4, 2], 'B': [6, 3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (44, {'A': [3, 1], 'B': [5], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (44, {'A': [3], 'B': [5], 'C': [6, 4, 2, 1]})
# SOLUCAO ATUAL
# (44, {'A': [3, 1], 'B': [5, 2], 'C': [6, 4]})
# SOLUCAO ATUAL
# (44, {'A': [3], 'B': [5, 2, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (44, {'A': [4], 'B': [5, 2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (44, {'A': [4], 'B': [5, 2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (44, {'A': [4, 2, 1], 'B': [5], 'C': [6, 3]})
# SOLUCAO ATUAL
# (44, {'A': [4, 2], 'B': [5], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (44, {'A': [], 'B': [5, 3], 'C': [6, 4, 2, 1]})
# SOLUCAO ATUAL
# (44, {'A': [], 'B': [5, 2, 1], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (44, {'A': [4, 3], 'B': [5, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (44, {'A': [4, 2, 1], 'B': [5, 3], 'C': [6]})
# SOLUCAO ATUAL
# (44, {'A': [3, 1], 'B': [6, 4], 'C': [5, 2]})
# SOLUCAO ATUAL
# (44, {'A': [3], 'B': [6, 4], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (44, {'A': [3, 1], 'B': [6, 4, 2], 'C': [5]})
# SOLUCAO ATUAL
# (44, {'A': [3], 'B': [6, 4, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (44, {'A': [4], 'B': [6, 3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (44, {'A': [4], 'B': [6, 3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (44, {'A': [4, 2, 1], 'B': [6, 3], 'C': [5]})
# SOLUCAO ATUAL
# (44, {'A': [4, 2], 'B': [6, 3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (44, {'A': [], 'B': [6, 4, 3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (44, {'A': [], 'B': [6, 4, 2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (44, {'A': [4, 3], 'B': [6], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (44, {'A': [4, 2, 1], 'B': [6], 'C': [5, 3]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [5, 3], 'C': [6, 4, 2, 1]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [5, 2, 1], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (45, {'A': [4, 3], 'B': [5, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (45, {'A': [4, 2, 1], 'B': [5, 3], 'C': [6]})
# SOLUCAO ATUAL
# (45, {'A': [1], 'B': [5, 3], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [5, 3, 1], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (45, {'A': [1], 'B': [5, 2], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [5, 2], 'C': [6, 4, 3, 1]})
# SOLUCAO ATUAL
# (45, {'A': [4, 3, 1], 'B': [5, 2], 'C': [6]})
# SOLUCAO ATUAL
# (45, {'A': [4, 3], 'B': [5, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (45, {'A': [4, 2], 'B': [5, 3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (45, {'A': [4, 2], 'B': [5, 3], 'C': [6, 1]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [6, 4, 3], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [6, 4, 2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (45, {'A': [4, 3], 'B': [6], 'C': [5, 2, 1]})
# SOLUCAO ATUAL
# (45, {'A': [4, 2, 1], 'B': [6], 'C': [5, 3]})
# SOLUCAO ATUAL
# (45, {'A': [1], 'B': [6, 4, 3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [6, 4, 3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (45, {'A': [1], 'B': [6, 4, 2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (45, {'A': [], 'B': [6, 4, 2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (45, {'A': [4, 3, 1], 'B': [6], 'C': [5, 2]})
# SOLUCAO ATUAL
# (45, {'A': [4, 3], 'B': [6, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (45, {'A': [4, 2], 'B': [6, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (45, {'A': [4, 2], 'B': [6], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [5, 3], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (46, {'A': [], 'B': [5, 3, 1], 'C': [6, 4, 2]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [5, 2], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (46, {'A': [], 'B': [5, 2], 'C': [6, 4, 3, 1]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3, 1], 'B': [5, 2], 'C': [6]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3], 'B': [5, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (46, {'A': [4, 2], 'B': [5, 3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (46, {'A': [4, 2], 'B': [5, 3], 'C': [6, 1]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [5, 3, 2], 'C': [6, 4]})
# SOLUCAO ATUAL
# (46, {'A': [2], 'B': [5, 3, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [5], 'C': [6, 4, 3, 2]})
# SOLUCAO ATUAL
# (46, {'A': [2], 'B': [5], 'C': [6, 4, 3, 1]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3, 1], 'B': [5], 'C': [6, 2]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3, 2], 'B': [5], 'C': [6, 1]})
# SOLUCAO ATUAL
# (46, {'A': [4], 'B': [5, 3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (46, {'A': [4], 'B': [5, 3, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [6, 4, 3], 'C': [5, 2]})
# SOLUCAO ATUAL
# (46, {'A': [], 'B': [6, 4, 3, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [6, 4, 2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (46, {'A': [], 'B': [6, 4, 2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3, 1], 'B': [6], 'C': [5, 2]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3], 'B': [6, 1], 'C': [5, 2]})
# SOLUCAO ATUAL
# (46, {'A': [4, 2], 'B': [6, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (46, {'A': [4, 2], 'B': [6], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [6, 4, 3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (46, {'A': [2], 'B': [6, 4, 3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (46, {'A': [1], 'B': [6, 4], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (46, {'A': [2], 'B': [6, 4], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3, 1], 'B': [6, 2], 'C': [5]})
# SOLUCAO ATUAL
# (46, {'A': [4, 3, 2], 'B': [6, 1], 'C': [5]})
# SOLUCAO ATUAL
# (46, {'A': [4], 'B': [6, 1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (46, {'A': [4], 'B': [6, 2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (47, {'A': [1], 'B': [5, 3, 2], 'C': [6, 4]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [5, 3, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (47, {'A': [1], 'B': [5], 'C': [6, 4, 3, 2]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [5], 'C': [6, 4, 3, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 1], 'B': [5], 'C': [6, 2]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 2], 'B': [5], 'C': [6, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [5, 3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [5, 3, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [5, 3, 2, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [5, 3, 2], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (47, {'A': [2, 1], 'B': [5, 3], 'C': [6, 4]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [5, 3], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [5, 1], 'C': [6, 4, 3, 2]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [5], 'C': [6, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (47, {'A': [2, 1], 'B': [5], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [5, 1], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3], 'B': [5, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3], 'B': [5], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 2, 1], 'B': [5], 'C': [6]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 2], 'B': [5, 1], 'C': [6]})
# SOLUCAO ATUAL
# (47, {'A': [4, 1], 'B': [5, 3], 'C': [6, 2]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [5, 3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 1], 'B': [5, 3, 2], 'C': [6]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [5, 3, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (47, {'A': [1], 'B': [6, 4, 3, 2], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [6, 4, 3, 1], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [1], 'B': [6, 4], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [6, 4], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 1], 'B': [6, 2], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 2], 'B': [6, 1], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [6, 1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [6, 2], 'C': [5, 3, 1]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [6, 4, 3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [6, 4, 3, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (47, {'A': [2, 1], 'B': [6, 4, 3], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [6, 4, 3], 'C': [5, 1]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [6, 4, 1], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (47, {'A': [], 'B': [6, 4], 'C': [5, 3, 2, 1]})
# SOLUCAO ATUAL
# (47, {'A': [2, 1], 'B': [6, 4], 'C': [5, 3]})
# SOLUCAO ATUAL
# (47, {'A': [2], 'B': [6, 4, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3], 'B': [6, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3], 'B': [6, 2], 'C': [5, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 2, 1], 'B': [6], 'C': [5]})
# SOLUCAO ATUAL
# (47, {'A': [4, 3, 2], 'B': [6], 'C': [5, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 1], 'B': [6], 'C': [5, 3, 2]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [6], 'C': [5, 3, 2, 1]})
# SOLUCAO ATUAL
# (47, {'A': [4, 1], 'B': [6, 2], 'C': [5, 3]})
# SOLUCAO ATUAL
# (47, {'A': [4], 'B': [6, 2, 1], 'C': [5, 3]})
# SOLUCAO ATUAL
# (48, {'A': [], 'B': [5, 3, 2, 1], 'C': [6, 4]})
# SOLUCAO ATUAL
# (48, {'A': [], 'B': [5, 3, 2], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (48, {'A': [2, 1], 'B': [5, 3], 'C': [6, 4]})
# SOLUCAO ATUAL
# (48, {'A': [2], 'B': [5, 3], 'C': [6, 4, 1]})
# SOLUCAO ATUAL
# (48, {'A': [], 'B': [5, 1], 'C': [6, 4, 3, 2]})
# SOLUCAO ATUAL
# (48, {'A': [], 'B': [5], 'C': [6, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (48, {'A': [2, 1], 'B': [5], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (48, {'A': [2], 'B': [5, 1], 'C': [6, 4, 3]})
# SOLUCAO ATUAL
# (48, {'A': [4, 3], 'B': [5, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (48, {'A': [4, 3], 'B': [5], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (48, {'A': [4, 3, 2, 1], 'B': [5], 'C': [6]})
# SOLUCAO ATUAL
# (48, {'A': [4, 3, 2], 'B': [5, 1], 'C': [6]})
# SOLUCAO ATUAL
# (48, {'A': [4, 1], 'B': [5, 3], 'C': [6, 2]})
# SOLUCAO ATUAL
# (48, {'A': [4], 'B': [5, 3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (48, {'A': [4, 1], 'B': [5, 3, 2], 'C': [6]})
# SOLUCAO ATUAL
# (48, {'A': [4], 'B': [5, 3, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (48, {'A': [5], 'B': [], 'C': [6, 4, 3, 2, 1]})
# SOLUCAO ATUAL
# (48, {'A': [4, 3, 2, 1], 'B': [], 'C': [6, 5]})
# SOLUCAO ATUAL
# (48, {'A': [], 'B': [6, 4, 3, 2, 1], 'C': [5]})
# SOLUCAO ATUAL
# ...
# SOLUCAO ATUAL
# (59, {'A': [5, 4], 'B': [6, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (59, {'A': [5, 4], 'B': [6, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (59, {'A': [5, 4, 2, 1], 'B': [6], 'C': [3]})
# SOLUCAO ATUAL
# (59, {'A': [5, 4, 2], 'B': [6], 'C': [3, 1]})
# SOLUCAO ATUAL
# (59, {'A': [], 'B': [6, 5, 3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (59, {'A': [], 'B': [6, 5, 3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (59, {'A': [2, 1], 'B': [6, 5, 3], 'C': [4]})
# SOLUCAO ATUAL
# (59, {'A': [2], 'B': [6, 5, 3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (59, {'A': [], 'B': [6, 5, 4, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (59, {'A': [], 'B': [6, 5, 4, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (59, {'A': [2, 1], 'B': [6, 5, 4], 'C': [3]})
# SOLUCAO ATUAL
# (59, {'A': [2], 'B': [6, 5, 4], 'C': [3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3, 1], 'B': [4], 'C': [6, 2]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3], 'B': [4], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3, 1], 'B': [4, 2], 'C': [6]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3], 'B': [4, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4], 'B': [3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4], 'B': [3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 2, 1], 'B': [3], 'C': [6]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 2], 'B': [3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [3, 1], 'C': [6, 5, 4, 2]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [3], 'C': [6, 5, 4, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [3], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (60, {'A': [2], 'B': [3, 1], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [4, 2, 1], 'C': [6, 5, 3]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [4, 2], 'C': [6, 5, 3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [4], 'C': [6, 5, 3]})
# SOLUCAO ATUAL
# (60, {'A': [2], 'B': [4], 'C': [6, 5, 3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5], 'B': [4, 3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5], 'B': [4, 2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 3], 'B': [], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 2, 1], 'B': [], 'C': [6, 3]})
# SOLUCAO ATUAL
# (60, {'A': [3], 'B': [], 'C': [6, 5, 4, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [], 'C': [6, 5, 4, 3]})
# SOLUCAO ATUAL
# (60, {'A': [3], 'B': [4, 2, 1], 'C': [6, 5]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [4, 3], 'C': [6, 5]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3, 1], 'B': [6], 'C': [4, 2]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3], 'B': [6], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3, 1], 'B': [6, 2], 'C': [4]})
# SOLUCAO ATUAL
# (60, {'A': [5, 3], 'B': [6, 2, 1], 'C': [4]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4], 'B': [6, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4], 'B': [6, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 2, 1], 'B': [6], 'C': [3]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 2], 'B': [6], 'C': [3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [6, 5, 3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [6, 5, 3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [6, 5, 3], 'C': [4]})
# SOLUCAO ATUAL
# (60, {'A': [2], 'B': [6, 5, 3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [6, 5, 4, 2, 1], 'C': [3]})
# SOLUCAO ATUAL
# (60, {'A': [], 'B': [6, 5, 4, 2], 'C': [3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [6, 5, 4], 'C': [3]})
# SOLUCAO ATUAL
# (60, {'A': [2], 'B': [6, 5, 4], 'C': [3, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5], 'B': [6, 3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [5], 'B': [6, 2, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 3], 'B': [6, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (60, {'A': [5, 4, 2, 1], 'B': [6, 3], 'C': []})
# SOLUCAO ATUAL
# (60, {'A': [3], 'B': [6, 5], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [6, 5], 'C': [4, 3]})
# SOLUCAO ATUAL
# (60, {'A': [3], 'B': [6, 5, 4, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (60, {'A': [2, 1], 'B': [6, 5, 4, 3], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [4, 3], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [4, 2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 3], 'B': [], 'C': [6, 2, 1]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 2, 1], 'B': [], 'C': [6, 3]})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [], 'C': [6, 5, 4, 2, 1]})
# SOLUCAO ATUAL
# (61, {'A': [2, 1], 'B': [], 'C': [6, 5, 4, 3]})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [4, 2, 1], 'C': [6, 5]})
# SOLUCAO ATUAL
# (61, {'A': [2, 1], 'B': [4, 3], 'C': [6, 5]})
# SOLUCAO ATUAL
# (61, {'A': [5, 1], 'B': [4, 3], 'C': [6, 2]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [4, 3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (61, {'A': [5, 1], 'B': [4, 2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [4, 2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 3, 1], 'B': [], 'C': [6, 2]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 3], 'B': [1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 2], 'B': [1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 2], 'B': [], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (61, {'A': [3, 1], 'B': [], 'C': [6, 5, 4, 2]})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [1], 'C': [6, 5, 4, 2]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [1], 'C': [6, 5, 4, 3]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [], 'C': [6, 5, 4, 3, 1]})
# SOLUCAO ATUAL
# (61, {'A': [3, 1], 'B': [4, 2], 'C': [6, 5]})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [4, 2], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [4, 3, 1], 'C': [6, 5]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [4, 3], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [6, 3], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [6, 2, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 3], 'B': [6, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 2, 1], 'B': [6, 3], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [6, 5], 'C': [4, 2, 1]})
# SOLUCAO ATUAL
# (61, {'A': [2, 1], 'B': [6, 5], 'C': [4, 3]})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [6, 5, 4, 2, 1], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [2, 1], 'B': [6, 5, 4, 3], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [5, 1], 'B': [6, 3], 'C': [4, 2]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [6, 3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (61, {'A': [5, 1], 'B': [6, 2], 'C': [4, 3]})
# SOLUCAO ATUAL
# (61, {'A': [5], 'B': [6, 2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 3, 1], 'B': [6, 2], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 3], 'B': [6, 2], 'C': [1]})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 2], 'B': [6, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [5, 4, 2], 'B': [6, 3], 'C': [1]})
# SOLUCAO ATUAL
# (61, {'A': [3, 1], 'B': [6, 5], 'C': [4, 2]})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [6, 5, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [6, 5, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [6, 5], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (61, {'A': [3, 1], 'B': [6, 5, 4, 2], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [3], 'B': [6, 5, 4, 2], 'C': [1]})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [6, 5, 4, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (61, {'A': [2], 'B': [6, 5, 4, 3], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [4, 3], 'C': [6, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5], 'B': [4, 3, 1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [4, 2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (62, {'A': [5], 'B': [4, 2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3, 1], 'B': [], 'C': [6, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3], 'B': [1], 'C': [6, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 2], 'B': [1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 2], 'B': [], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [], 'C': [6, 5, 4, 2]})
# SOLUCAO ATUAL
# (62, {'A': [3], 'B': [1], 'C': [6, 5, 4, 2]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [1], 'C': [6, 5, 4, 3]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [], 'C': [6, 5, 4, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [4, 2], 'C': [6, 5]})
# SOLUCAO ATUAL
# (62, {'A': [3], 'B': [4, 2], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [4, 3, 1], 'C': [6, 5]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [4, 3], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [4, 3, 2], 'C': [6]})
# SOLUCAO ATUAL
# (62, {'A': [5, 2], 'B': [4, 3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [4], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 2], 'B': [4], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3, 1], 'B': [2], 'C': [6]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3, 2], 'B': [1], 'C': [6]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4], 'B': [1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4], 'B': [2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [2], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (62, {'A': [3, 2], 'B': [1], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [1], 'C': [6, 5, 4, 3, 2]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [2], 'C': [6, 5, 4, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [4], 'C': [6, 5, 2]})
# SOLUCAO ATUAL
# (62, {'A': [3, 2], 'B': [4], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [4, 3, 1], 'C': [6, 5, 2]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [4, 3, 2], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [6, 3], 'C': [4, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5], 'B': [6, 3, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [6, 2], 'C': [4, 3]})
# SOLUCAO ATUAL
# (62, {'A': [5], 'B': [6, 2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3, 1], 'B': [6, 2], 'C': []})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3], 'B': [6, 2], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 2], 'B': [6, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 2], 'B': [6, 3], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [6, 5], 'C': [4, 2]})
# SOLUCAO ATUAL
# (62, {'A': [3], 'B': [6, 5, 1], 'C': [4, 2]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [6, 5, 1], 'C': [4, 3]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [6, 5], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [6, 5, 4, 2], 'C': []})
# SOLUCAO ATUAL
# (62, {'A': [3], 'B': [6, 5, 4, 2], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [6, 5, 4, 3, 1], 'C': []})
# SOLUCAO ATUAL
# (62, {'A': [2], 'B': [6, 5, 4, 3], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [6, 3, 2], 'C': [4]})
# SOLUCAO ATUAL
# (62, {'A': [5, 2], 'B': [6, 3, 1], 'C': [4]})
# SOLUCAO ATUAL
# (62, {'A': [5, 1], 'B': [6], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 2], 'B': [6], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3, 1], 'B': [6], 'C': [2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4, 3, 2], 'B': [6], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4], 'B': [6, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (62, {'A': [5, 4], 'B': [6, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [6, 5, 2], 'C': [4]})
# SOLUCAO ATUAL
# (62, {'A': [3, 2], 'B': [6, 5, 1], 'C': [4]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [6, 5, 1], 'C': [4, 3, 2]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [6, 5, 2], 'C': [4, 3, 1]})
# SOLUCAO ATUAL
# (62, {'A': [3, 1], 'B': [6, 5, 4], 'C': [2]})
# SOLUCAO ATUAL
# (62, {'A': [3, 2], 'B': [6, 5, 4], 'C': [1]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [6, 5, 4, 3, 1], 'C': [2]})
# SOLUCAO ATUAL
# (62, {'A': [], 'B': [6, 5, 4, 3, 2], 'C': [1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 1], 'B': [4, 3, 2], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 2], 'B': [4, 3, 1], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 1], 'B': [4], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (63, {'A': [5, 2], 'B': [4], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 3, 1], 'B': [2], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 3, 2], 'B': [1], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4], 'B': [1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4], 'B': [2], 'C': [6, 3, 1]})
# SOLUCAO ATUAL
# (63, {'A': [3, 1], 'B': [2], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (63, {'A': [3, 2], 'B': [1], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (63, {'A': [], 'B': [1], 'C': [6, 5, 4, 3, 2]})
# SOLUCAO ATUAL
# (63, {'A': [], 'B': [2], 'C': [6, 5, 4, 3, 1]})
# SOLUCAO ATUAL
# (63, {'A': [3, 1], 'B': [4], 'C': [6, 5, 2]})
# SOLUCAO ATUAL
# (63, {'A': [3, 2], 'B': [4], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (63, {'A': [], 'B': [4, 3, 1], 'C': [6, 5, 2]})
# SOLUCAO ATUAL
# (63, {'A': [], 'B': [4, 3, 2], 'C': [6, 5, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5], 'B': [4, 3, 2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5], 'B': [4, 3, 2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 2, 1], 'B': [4, 3], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 2], 'B': [4, 3], 'C': [6, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5], 'B': [4, 1], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (63, {'A': [5], 'B': [4], 'C': [6, 3, 2, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 2, 1], 'B': [4], 'C': [6, 3]})
# SOLUCAO ATUAL
# (63, {'A': [5, 2], 'B': [4, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 3], 'B': [2, 1], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 3], 'B': [2], 'C': [6, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 3, 2, 1], 'B': [], 'C': [6]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 3, 2], 'B': [], 'C': [6, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 1], 'B': [], 'C': [6, 3, 2]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4], 'B': [], 'C': [6, 3, 2, 1]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4, 1], 'B': [2], 'C': [6, 3]})
# SOLUCAO ATUAL
# (63, {'A': [5, 4], 'B': [2, 1], 'C': [6, 3]})
# SOLUCAO ATUAL
# (63, {'A': [3], 'B': [2, 1], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (63, {'A': [3], 'B': [2], 'C': [6, 5, 4, 1]})
# SOLUCAO ATUAL
# (63, {'A': [3, 2, 1], 'B': [], 'C': [6, 5, 4]})
# SOLUCAO ATUAL
# (63, {'A': [3, 2], 'B': [], 'C': [6, 5, 4, 1]})
# SOLUCAO ATUAL
# (63, {'A': [1], 'B': [], 'C': [6, 5, 4, 3, 2]})
# SOLUCAO ATUAL
# (63, {'A': [], 'B': [], 'C': [6, 5, 4, 3, 2, 1]})
# SOLUCAO FINAL
# (63, {'A': [], 'B': [], 'C': [6, 5, 4, 3, 2, 1]})
# Caminho
# [(0, {'A': [6, 5, 4, 3, 2, 1], 'B': [], 'C': []}),
#  (1, {'A': [6, 5, 4, 3, 2], 'B': [1], 'C': []}),
#  (2, {'A': [6, 5, 4, 3], 'B': [1], 'C': [2]}),
#  (3, {'A': [6, 5, 4, 3], 'B': [], 'C': [2, 1]}),
#  (4, {'A': [6, 5, 4], 'B': [3], 'C': [2, 1]}),
#  (5, {'A': [6, 5, 4, 1], 'B': [3], 'C': [2]}),
#  (6, {'A': [6, 5, 4, 1], 'B': [3, 2], 'C': []}),
#  (7, {'A': [6, 5, 4], 'B': [3, 2, 1], 'C': []}),
#  (8, {'A': [6, 5], 'B': [3, 2, 1], 'C': [4]}),
#  (9, {'A': [6, 5], 'B': [3, 2], 'C': [4, 1]}),
#  (10, {'A': [6, 5, 2], 'B': [3], 'C': [4, 1]}),
#  (11, {'A': [6, 5, 2, 1], 'B': [3], 'C': [4]}),
#  (12, {'A': [6, 5, 2, 1], 'B': [], 'C': [4, 3]}),
#  (13, {'A': [6, 5, 2], 'B': [1], 'C': [4, 3]}),
#  (14, {'A': [6, 5], 'B': [1], 'C': [4, 3, 2]}),
#  (15, {'A': [6, 5], 'B': [], 'C': [4, 3, 2, 1]}),
#  (16, {'A': [6], 'B': [5], 'C': [4, 3, 2, 1]}),
#  (17, {'A': [6, 1], 'B': [5], 'C': [4, 3, 2]}),
#  (18, {'A': [6, 1], 'B': [5, 2], 'C': [4, 3]}),
#  (19, {'A': [6], 'B': [5, 2, 1], 'C': [4, 3]}),
#  (20, {'A': [6, 3], 'B': [5, 2, 1], 'C': [4]}),
#  (21, {'A': [6, 3], 'B': [5, 2], 'C': [4, 1]}),
#  (22, {'A': [6, 3, 2], 'B': [5], 'C': [4, 1]}),
#  (23, {'A': [6, 3, 2, 1], 'B': [5], 'C': [4]}),
#  (24, {'A': [6, 3, 2, 1], 'B': [5, 4], 'C': []}),
#  (25, {'A': [6, 3, 2], 'B': [5, 4, 1], 'C': []}),
#  (26, {'A': [6, 3], 'B': [5, 4, 1], 'C': [2]}),
#  (27, {'A': [6, 3], 'B': [5, 4], 'C': [2, 1]}),
#  (28, {'A': [6], 'B': [5, 4, 3], 'C': [2, 1]}),
#  (29, {'A': [6, 1], 'B': [5, 4, 3], 'C': [2]}),
#  (30, {'A': [6, 1], 'B': [5, 4, 3, 2], 'C': []}),
#  (31, {'A': [6], 'B': [5, 4, 3, 2, 1], 'C': []}),
#  (32, {'A': [], 'B': [5, 4, 3, 2, 1], 'C': [6]}),
#  (33, {'A': [], 'B': [5, 4, 3, 2], 'C': [6, 1]}),
#  (34, {'A': [2], 'B': [5, 4, 3], 'C': [6, 1]}),
#  (35, {'A': [2, 1], 'B': [5, 4, 3], 'C': [6]}),
#  (36, {'A': [2, 1], 'B': [5, 4], 'C': [6, 3]}),
#  (37, {'A': [2], 'B': [5, 4, 1], 'C': [6, 3]}),
#  (38, {'A': [], 'B': [5, 4, 1], 'C': [6, 3, 2]}),
#  (39, {'A': [], 'B': [5, 4], 'C': [6, 3, 2, 1]}),
#  (40, {'A': [4], 'B': [5], 'C': [6, 3, 2, 1]}),
#  (41, {'A': [4, 1], 'B': [5], 'C': [6, 3, 2]}),
#  (42, {'A': [4, 1], 'B': [5, 2], 'C': [6, 3]}),
#  (43, {'A': [4], 'B': [5, 2, 1], 'C': [6, 3]}),
#  (44, {'A': [4, 3], 'B': [5, 2, 1], 'C': [6]}),
#  (45, {'A': [4, 3], 'B': [5, 2], 'C': [6, 1]}),
#  (46, {'A': [4, 3, 2], 'B': [5], 'C': [6, 1]}),
#  (47, {'A': [4, 3, 2, 1], 'B': [5], 'C': [6]}),
#  (48, {'A': [4, 3, 2, 1], 'B': [], 'C': [6, 5]}),
#  (49, {'A': [4, 3, 2], 'B': [1], 'C': [6, 5]}),
#  (50, {'A': [4, 3], 'B': [1], 'C': [6, 5, 2]}),
#  (51, {'A': [4, 3], 'B': [], 'C': [6, 5, 2, 1]}),
#  (52, {'A': [4], 'B': [3], 'C': [6, 5, 2, 1]}),
#  (53, {'A': [4, 1], 'B': [3], 'C': [6, 5, 2]}),
#  (54, {'A': [4, 1], 'B': [3, 2], 'C': [6, 5]}),
#  (55, {'A': [4], 'B': [3, 2, 1], 'C': [6, 5]}),
#  (56, {'A': [], 'B': [3, 2, 1], 'C': [6, 5, 4]}),
#  (57, {'A': [], 'B': [3, 2], 'C': [6, 5, 4, 1]}),
#  (58, {'A': [2], 'B': [3], 'C': [6, 5, 4, 1]}),
#  (59, {'A': [2, 1], 'B': [3], 'C': [6, 5, 4]}),
#  (60, {'A': [2, 1], 'B': [], 'C': [6, 5, 4, 3]}),
#  (61, {'A': [2], 'B': [1], 'C': [6, 5, 4, 3]}),
#  (62, {'A': [], 'B': [1], 'C': [6, 5, 4, 3, 2]}),
#  (63, {'A': [], 'B': [], 'C': [6, 5, 4, 3, 2, 1]})]
# Resultado alcancado apos 1332 buscas.
# -------------------FIM LARGURA-------------------
